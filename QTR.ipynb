# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [curl_cffi]
#    ---------------------------------------- 0/2 [curl_cffi]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    ---------------------------------------- 2/2 [yfinance]
#
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start ="2010-01-01",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\4118616119.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Apple = yf.download("AAPL", start ="2010-01-01",end ="2025-01-01" )
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.431899    6.446625    6.382910    6.414467  493729600
# 2010-01-05    6.443017    6.479383    6.409056    6.449630  601904800
# 2010-01-06    6.340530    6.468561    6.333918    6.443015  552160000
# 2010-01-07    6.328810    6.371487    6.282827    6.363974  477131200
# 2010-01-08    6.370888    6.371489    6.283130    6.320397  447610800
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.578674  257.588630  254.675658  254.875189   23234700
# 2024-12-26  258.396667  259.474086  257.010028  257.568678   27237100
# 2024-12-27  254.974930  258.077462  252.451019  257.209530   42355300
# 2024-12-30  251.593079  252.889953  250.146571  251.623005   35557500
# 2024-12-31  249.817368  252.670486  248.829744  251.832511   39480700
#
# [3774 rows x 5 columns]

# %%
a = [1,2,3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker=["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2413046575.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.431899  17.692514   85.515617    6.446625  17.748346
# 2010-01-05    6.443017  17.478491   85.742004    6.479383  17.677005
# 2010-01-06    6.340530  17.472290   85.802376    6.468561  17.506409
# 2010-01-07    6.328810  17.428864   86.164589    6.371487  17.484696
# 2010-01-08    6.370888  17.106283   86.451309    6.371489  17.258269
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.578674  61.939281  597.729553  257.588630  61.939281
# 2024-12-26  258.396667  61.673145  597.769348  259.474086  61.840711
# 2024-12-27  254.974930  61.554871  591.476868  258.077462  62.047704
# 2024-12-30  251.593079  61.140888  584.727173  252.889953  61.446446
# 2024-12-31  249.817368  61.367588  582.599915  252.670486  61.535153
#
# ...

# %%
stocks.head()
# Out:
# Price          Close                            High                        \
# Ticker          AAPL         KO        SPY      AAPL         KO        SPY
# Date
# 2010-01-04  6.431899  17.692514  85.515617  6.446625  17.748346  85.560890
# 2010-01-05  6.443017  17.478491  85.742004  6.479383  17.677005  85.779735
# 2010-01-06  6.340530  17.472290  85.802376  6.468561  17.506409  86.013655
# 2010-01-07  6.328810  17.428864  86.164589  6.371487  17.484696  86.270229
# 2010-01-08  6.370888  17.106283  86.451309  6.371489  17.258269  86.489040
#
# Price            Low                            Open                        \
# Ticker          AAPL         KO        SPY      AAPL         KO        SPY
# Date
# 2010-01-04  6.382910  17.649090  84.142297  6.414467  17.729735  84.791229
# 2010-01-05  6.409056  17.413354  85.153439  6.449630  17.633579  85.462816
# 2010-01-06  6.333918  17.363727  85.591097  6.443015  17.478493  85.659005
# ...

# %%
stocks.tail()
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2024-12-24  257.578674  61.939281  597.729553  257.588630  61.939281
# 2024-12-26  258.396667  61.673145  597.769348  259.474086  61.840711
# 2024-12-27  254.974930  61.554871  591.476868  258.077462  62.047704
# 2024-12-30  251.593079  61.140888  584.727173  252.889953  61.446446
# 2024-12-31  249.817368  61.367588  582.599915  252.670486  61.535153
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2024-12-24  597.769355  254.675658  61.121176  591.934154  254.875189
# 2024-12-26  598.902533  257.010028  61.505584  594.528696  257.568678
# 2024-12-27  594.230439  252.451019  61.318309  587.252104  257.209530
# 2024-12-30  588.226291  250.146571  60.795906  580.939799  251.623005
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3774 entries, 2010-01-04 to 2024-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   3774 non-null   float64
#  1   (Close, KO)     3774 non-null   float64
#  2   (Close, SPY)    3774 non-null   float64
#  3   (High, AAPL)    3774 non-null   float64
#  4   (High, KO)      3774 non-null   float64
#  5   (High, SPY)     3774 non-null   float64
#  6   (Low, AAPL)     3774 non-null   float64
#  7   (Low, KO)       3774 non-null   float64
#  8   (Low, SPY)      3774 non-null   float64
#  9   (Open, AAPL)    3774 non-null   float64
#  10  (Open, KO)      3774 non-null   float64
#  11  (Open, SPY)     3774 non-null   float64
#  12  (Volume, AAPL)  3774 non-null   int64
#  13  (Volume, KO)    3774 non-null   int64
#  14  (Volume, SPY)   3774 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 471.8 KB

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])

# %%
stocks

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0])
stocks

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0],parse_dates=[0])
stocks

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#                  Close                               High             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.431899  17.692514   85.515617    6.446625  17.748346
# 2010-01-05    6.443017  17.478491   85.742004    6.479383  17.677005
# 2010-01-06    6.340530  17.472290   85.802376    6.468561  17.506409
# 2010-01-07    6.328810  17.428864   86.164589    6.371487  17.484696
# 2010-01-08    6.370888  17.106283   86.451309    6.371489  17.258269
# ...                ...        ...         ...         ...        ...
# 2024-12-24  257.578674  61.939281  597.729553  257.588630  61.939281
# 2024-12-26  258.396667  61.673145  597.769348  259.474086  61.840711
# 2024-12-27  254.974930  61.554871  591.476868  258.077462  62.047704
# 2024-12-30  251.593079  61.140888  584.727173  252.889953  61.446446
# 2024-12-31  249.817368  61.367588  582.599915  252.670486  61.535153
#
# ...

# %%
stocks.describe()
# Out:
#              Close                                   High               \
#               AAPL           KO          SPY         AAPL           KO
# count  3774.000000  3774.000000  3774.000000  3774.000000  3774.000000
# mean     67.433262    37.412095   247.221052    68.086941    37.657024
# std      65.516757    13.202488   132.267890    66.125667    13.298266
# min       5.771907    15.660820    77.803238     5.890622    15.862685
# 25%      17.438811    27.522151   138.376408    17.622326    27.688026
# 50%      35.277460    34.426266   213.382271    35.681951    34.682521
# 75%     126.743399    47.783631   362.305260   127.831544    48.055683
# max     258.396667    70.935501   602.174133   259.474086    71.440715
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  3774.000000  3774.000000  3774.000000  3774.000000  3774.000000
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    6.431899  17.692514   85.515617
# 2010-01-05    6.443017  17.478491   85.742004
# 2010-01-06    6.340530  17.472290   85.802376
# 2010-01-07    6.328810  17.428864   86.164589
# 2010-01-08    6.370888  17.106283   86.451309
# ...                ...        ...         ...
# 2024-12-24  257.578674  61.939281  597.729553
# 2024-12-26  258.396667  61.673145  597.769348
# 2024-12-27  254.974930  61.554871  591.476868
# 2024-12-30  251.593079  61.140888  584.727173
# 2024-12-31  249.817368  61.367588  582.599915
#
# [3774 rows x 3 columns]

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    6.431899  17.692514   85.515617
# 2010-01-05    6.443017  17.478491   85.742004
# 2010-01-06    6.340530  17.472290   85.802376
# 2010-01-07    6.328810  17.428864   86.164589
# 2010-01-08    6.370888  17.106283   86.451309
# ...                ...        ...         ...
# 2024-12-24  257.578674  61.939281  597.729553
# 2024-12-26  258.396667  61.673145  597.769348
# 2024-12-27  254.974930  61.554871  591.476868
# 2024-12-30  251.593079  61.140888  584.727173
# 2024-12-31  249.817368  61.367588  582.599915
#
# [3774 rows x 3 columns]

# %%
# %matplotlib inline
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")  # Optional aesthetic

import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/8.1 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 2.6 MB/s eta 0:00:02
# ...

# %%
close.plot(figsize=(15,9),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# np.float64(6.431898593902588)

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      6.431899
# 2010-01-05      6.443017
# 2010-01-06      6.340530
# 2010-01-07      6.328810
# 2010-01-08      6.370888
#                  ...
# 2024-12-24    257.578674
# 2024-12-26    258.396667
# 2024-12-27    254.974930
# 2024-12-30    251.593079
# 2024-12-31    249.817368
# Name: AAPL, Length: 3774, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983972
# 2010-01-08     0.990514
#                 ...
# 2024-12-24    40.047067
# 2024-12-26    40.174245
# 2024-12-27    39.642250
# 2024-12-30    39.116456
# 2024-12-31    38.840377
# Name: AAPL, Length: 3774, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172871
# 2010-01-06      98.579452
# 2010-01-07      98.397225
# 2010-01-08      99.051433
#                  ...
# 2024-12-24    4004.706706
# 2024-12-26    4017.424462
# 2024-12-27    3964.224965
# 2024-12-30    3911.645604
# 2024-12-31    3884.037721
# Name: AAPL, Length: 3774, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     6.431899
# KO      17.692514
# SPY     85.515617
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172871   98.790316  100.264732
# 2010-01-06    98.579452   98.755268  100.335329
# 2010-01-07    98.397225   98.509817  100.758892
# 2010-01-08    99.051433   96.686558  101.094177
# ...                 ...         ...         ...
# 2024-12-24  4004.706706  350.087500  698.971219
# 2024-12-26  4017.424462  348.583270  699.017754
# 2024-12-27  3964.224965  347.914769  691.659472
# 2024-12-30  3911.645604  345.574895  683.766534
# 2024-12-31  3884.037721  346.856227  681.278967
#
# [3774 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,9),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    6.431899
# 2010-01-05    6.443017
# 2010-01-06    6.340530
# 2010-01-07    6.328810
# 2010-01-08    6.370888
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593079
# 2024-12-31  249.817368
#
# [3774 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    6.431899
# 2010-01-06    6.443017
# 2010-01-07    6.340530
# 2010-01-08    6.328810
# ...                ...
# 2024-12-24  254.655716
# 2024-12-26  257.578674
# 2024-12-27  258.396667
# 2024-12-30  254.974930
# 2024-12-31  251.593079
#
# [3774 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    6.431899         NaN
# 2010-01-05    6.443017    6.431899
# 2010-01-06    6.340530    6.443017
# 2010-01-07    6.328810    6.340530
# 2010-01-08    6.370888    6.328810
# ...                ...         ...
# 2024-12-24  257.578674  254.655716
# 2024-12-26  258.396667  257.578674
# 2024-12-27  254.974930  258.396667
# 2024-12-30  251.593079  254.974930
# 2024-12-31  249.817368  251.593079
#
# [3774 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    6.431899         NaN       NaN
# 2010-01-05    6.443017    6.431899  0.011119
# 2010-01-06    6.340530    6.443017 -0.102487
# 2010-01-07    6.328810    6.340530 -0.011721
# 2010-01-08    6.370888    6.328810  0.042078
# ...                ...         ...       ...
# 2024-12-24  257.578674  254.655716  2.922958
# 2024-12-26  258.396667  257.578674  0.817993
# 2024-12-27  254.974930  258.396667 -3.421738
# 2024-12-30  251.593079  254.974930 -3.381851
# 2024-12-31  249.817368  251.593079 -1.775711
#
# [3774 rows x 3 columns]

# %%
aapl["%Change"]=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %Change
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.172871
# 2010-01-06    6.340530    6.443017 -0.102487 -1.590669
# 2010-01-07    6.328810    6.340530 -0.011721 -0.184853
# 2010-01-08    6.370888    6.328810  0.042078  0.664865
# ...                ...         ...       ...       ...
# 2024-12-24  257.578674  254.655716  2.922958  1.147808
# 2024-12-26  258.396667  257.578674  0.817993  0.317570
# 2024-12-27  254.974930  258.396667 -3.421738 -1.324219
# 2024-12-30  251.593079  254.974930 -3.381851 -1.326347
# 2024-12-31  249.817368  251.593079 -1.775711 -0.705787
#
# [3774 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %Change     Diff2
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN       NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.172871  0.011119
# 2010-01-06    6.340530    6.443017 -0.102487 -1.590669 -0.102487
# 2010-01-07    6.328810    6.340530 -0.011721 -0.184853 -0.011721
# 2010-01-08    6.370888    6.328810  0.042078  0.664865  0.042078
# ...                ...         ...       ...       ...       ...
# 2024-12-24  257.578674  254.655716  2.922958  1.147808  2.922958
# 2024-12-26  258.396667  257.578674  0.817993  0.317570  0.817993
# 2024-12-27  254.974930  258.396667 -3.421738 -1.324219 -3.421738
# 2024-12-30  251.593079  254.974930 -3.381851 -1.326347 -3.381851
# 2024-12-31  249.817368  251.593079 -1.775711 -0.705787 -1.775711
#
# [3774 rows x 5 columns]

# %%
aapl["%Change 2"]=aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff   %Change     Diff2  %Change 2
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN       NaN        NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.172871  0.011119   0.172871
# 2010-01-06    6.340530    6.443017 -0.102487 -1.590669 -0.102487  -1.590669
# 2010-01-07    6.328810    6.340530 -0.011721 -0.184853 -0.011721  -0.184853
# 2010-01-08    6.370888    6.328810  0.042078  0.664865  0.042078   0.664865
# ...                ...         ...       ...       ...       ...        ...
# 2024-12-24  257.578674  254.655716  2.922958  1.147808  2.922958   1.147808
# 2024-12-26  258.396667  257.578674  0.817993  0.317570  0.817993   0.317570
# 2024-12-27  254.974930  258.396667 -3.421738 -1.324219 -3.421738  -1.324219
# 2024-12-30  251.593079  254.974930 -3.381851 -1.326347 -3.381851  -1.326347
# 2024-12-31  249.817368  251.593079 -1.775711 -0.705787 -1.775711  -0.705787
#
# [3774 rows x 6 columns]

# %%
del aapl["%Change"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2  %Change 2
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN        NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.011119   0.172871
# 2010-01-06    6.340530    6.443017 -0.102487 -0.102487  -1.590669
# 2010-01-07    6.328810    6.340530 -0.011721 -0.011721  -0.184853
# 2010-01-08    6.370888    6.328810  0.042078  0.042078   0.664865
# ...                ...         ...       ...       ...        ...
# 2024-12-24  257.578674  254.655716  2.922958  2.922958   1.147808
# 2024-12-26  258.396667  257.578674  0.817993  0.817993   0.317570
# 2024-12-27  254.974930  258.396667 -3.421738 -3.421738  -1.324219
# 2024-12-30  251.593079  254.974930 -3.381851 -3.381851  -1.326347
# 2024-12-31  249.817368  251.593079 -1.775711 -1.775711  -0.705787
#
# [3774 rows x 5 columns]

# %%
aapl.rename(columns = {'%Change 2':'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2    Change
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN       NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.011119  0.172871
# 2010-01-06    6.340530    6.443017 -0.102487 -0.102487 -1.590669
# 2010-01-07    6.328810    6.340530 -0.011721 -0.011721 -0.184853
# 2010-01-08    6.370888    6.328810  0.042078  0.042078  0.664865
# ...                ...         ...       ...       ...       ...
# 2024-12-24  257.578674  254.655716  2.922958  2.922958  1.147808
# 2024-12-26  258.396667  257.578674  0.817993  0.817993  0.317570
# 2024-12-27  254.974930  258.396667 -3.421738 -3.421738 -1.324219
# 2024-12-30  251.593079  254.974930 -3.381851 -3.381851 -1.326347
# 2024-12-31  249.817368  251.593079 -1.775711 -1.775711 -0.705787
#
# [3774 rows x 5 columns]

# %%
aapl.AAPL.resample("ME").last()
# Out:
# Date
# 2010-01-31      5.772208
# 2010-02-28      6.149687
# 2010-03-31      7.062733
# 2010-04-30      7.846851
# 2010-05-31      7.720320
#                  ...
# 2024-08-31    228.197845
# 2024-09-30    232.183853
# 2024-10-31    225.118683
# 2024-11-30    236.758865
# 2024-12-31    249.817368
# Freq: ME, Name: AAPL, Length: 180, dtype: float64

# %%
aapl.AAPL.resample("BME").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539604
# 2010-03-31    14.847022
# 2010-04-30    11.102192
# 2010-05-31    -1.612502
#                 ...
# 2024-08-30     3.235354
# 2024-09-30     1.746733
# 2024-10-31    -3.042921
# 2024-11-29     5.170687
# 2024-12-31     5.515528
# Freq: BME, Name: AAPL, Length: 180, dtype: float64

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2    Change
# Date
# 2010-01-04    6.431899         NaN       NaN       NaN       NaN
# 2010-01-05    6.443017    6.431899  0.011119  0.011119  0.172871
# 2010-01-06    6.340530    6.443017 -0.102487 -0.102487 -1.590669
# 2010-01-07    6.328810    6.340530 -0.011721 -0.011721 -0.184853
# 2010-01-08    6.370888    6.328810  0.042078  0.042078  0.664865
# ...                ...         ...       ...       ...       ...
# 2024-12-24  257.578674  254.655716  2.922958  2.922958  1.147808
# 2024-12-26  258.396667  257.578674  0.817993  0.817993  0.317570
# 2024-12-27  254.974930  258.396667 -3.421738 -3.421738 -1.324219
# 2024-12-30  251.593079  254.974930 -3.381851 -3.381851 -1.326347
# 2024-12-31  249.817368  251.593079 -1.775711 -1.775711 -0.705787
#
# [3774 rows x 5 columns]

# %%
del aapl["Change"]

# %%
del aapl["lag1"]

# %%
del aapl["Diff"]

# %%
del aapl["Diff2"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    6.431899
# 2010-01-05    6.443017
# 2010-01-06    6.340530
# 2010-01-07    6.328810
# 2010-01-08    6.370888
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593079
# 2024-12-31  249.817368
#
# [3774 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015907
# 2010-01-07 -0.001849
# 2010-01-08  0.006649
# 2010-01-11 -0.008822
# ...              ...
# 2024-12-24  0.011478
# 2024-12-26  0.003176
# 2024-12-27 -0.013242
# 2024-12-30 -0.013263
# 2024-12-31 -0.007058
#
# [3773 rows x 1 columns]

# %%
ret.info
# Out:
# <bound method DataFrame.info of                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015907
# 2010-01-07 -0.001849
# 2010-01-08  0.006649
# 2010-01-11 -0.008822
# ...              ...
# 2024-12-24  0.011478
# 2024-12-26  0.003176
# 2024-12-27 -0.013242
# 2024-12-30 -0.013263
# 2024-12-31 -0.007058
#
# [3773 rows x 1 columns]>

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001124
# dtype: float64

# %%
var_daily=ret.var()

# %%
var_daily
# Out:
# AAPL    0.000308
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.017552
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017552
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252

# %%
annual_mean_ret
# Out:
# AAPL    0.283364
# dtype: float64

# %%
annual_var_return=var_daily*252

# %%
annual_var_return
# Out:
# AAPL    0.077634
# dtype: float64

# %%
annual_std_return=np.sqrt(annual_var_return)

# %%
annual_std_return
# Out:
# AAPL    0.27863
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.27863
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2413046575.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# [*********************100%***********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
# Ticker            AAPL         DIS         IBM         KO        MSFT  \
# Date
# 2010-01-04    6.431899   27.475876   73.778778  17.692514   23.211439
# 2010-01-05    6.443017   27.407341   72.887573  17.478491   23.218937
# 2010-01-06    6.340530   27.261692   72.414085  17.472290   23.076447
# 2010-01-07    6.328810   27.270258   72.163414  17.428864   22.836460
# 2010-01-08    6.370888   27.313097   72.887573  17.106283   22.993952
# ...                ...         ...         ...        ...         ...
# 2024-12-24  257.578674  112.082031  221.451202  61.939281  437.647400
# 2024-12-26  258.396667  112.072083  221.924866  61.673145  436.432068
# 2024-12-27  254.974930  111.076332  219.842682  61.554871  428.881104
# 2024-12-30  251.593079  110.329514  217.346039  61.140888  423.202911
# 2024-12-31  249.817368  110.877174  216.931580  61.367588  419.885681
#
# Ticker             SPY
# Date
# 2010-01-04   85.515617
# 2010-01-05   85.742004
# 2010-01-06   85.802376
# ...

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,9),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012079 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015907 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006649  0.001571  0.010035 -0.018508  0.006897  0.003328
# 2010-01-11 -0.008822 -0.016311 -0.010470  0.020308 -0.012720  0.001396

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    3773.0  0.001124  0.017552 -0.128647 -0.007398  0.001001  0.010355
# DIS     3773.0  0.000505  0.016427 -0.131632 -0.006790  0.000443  0.008234
# IBM     3773.0  0.000384  0.013983 -0.128507 -0.006125  0.000554  0.007126
# KO      3773.0  0.000387  0.010725 -0.096725 -0.004609  0.000563  0.005735
# MSFT    3773.0  0.000897  0.016109 -0.147390 -0.007084  0.000695  0.009233
# SPY     3773.0  0.000567  0.010741 -0.109424 -0.003709  0.000682  0.005790
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113011
# KO      0.064795
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001124  0.017552
# DIS     0.000505  0.016427
# IBM     0.000384  0.013983
# KO      0.000387  0.010725
# MSFT    0.000897  0.016109
# SPY     0.000567  0.010741

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001124  0.017552
# DIS     0.000505  0.016427
# IBM     0.000384  0.013983
# KO      0.000387  0.010725
# MSFT    0.000897  0.016109
# SPY     0.000567  0.010741

# %%
summary["mean"]=summary["mean"] * 252
summary["std"]=summary["std"]*np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.283364  0.278630
# DIS     0.127154  0.260766
# IBM     0.096797  0.221967
# KO      0.097639  0.170251
# MSFT    0.226149  0.255728
# SPY     0.142780  0.170509

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/Return",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
fruits = ["apple", "banana","mango"]
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012079 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015907 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006649  0.001571  0.010035 -0.018508  0.006897  0.003328
# 2010-01-11 -0.008822 -0.016311 -0.010470  0.020308 -0.012720  0.001396
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011478  0.010413  0.011175  0.007374  0.009374  0.011115
# 2024-12-26  0.003176 -0.000089  0.002139 -0.004297 -0.002777  0.000067
# 2024-12-27 -0.013242 -0.008885 -0.009382 -0.001918 -0.017302 -0.010527
# 2024-12-30 -0.013263 -0.006723 -0.011356 -0.006725 -0.013240 -0.011412
# 2024-12-31 -0.007058  0.004964 -0.001907  0.003708 -0.007838 -0.003638
#
# [3773 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000308  0.000115  0.000096  0.000064  0.000166  0.000129
# DIS     0.000115  0.000270  0.000097  0.000074  0.000120  0.000118
# IBM     0.000096  0.000097  0.000196  0.000070  0.000102  0.000095
# KO      0.000064  0.000074  0.000070  0.000115  0.000069  0.000069
# MSFT    0.000166  0.000120  0.000102  0.000069  0.000260  0.000131
# SPY     0.000129  0.000118  0.000095  0.000069  0.000131  0.000115

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.398085  0.389218  0.341574  0.588434  0.684196
# DIS     0.398085  1.000000  0.421643  0.421947  0.452689  0.666879
# IBM     0.389218  0.421643  1.000000  0.465863  0.453813  0.635369
# KO      0.341574  0.421947  0.465863  1.000000  0.401016  0.597797
# MSFT    0.588434  0.452689  0.453813  0.401016  1.000000  0.754660
# SPY     0.684196  0.666879  0.635369  0.597797  0.754660  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
ticker=["SPY","NVDA","BRK","TSLA","JPM","GOOG","LLY","NFLX","XOM","V","MA","COST","WMT","XOM","PG","JNJ","PG","ORCL","HD","ABBV","PLTR","PM","WFC"]

# %%
stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2413046575.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start ="2010-01-01",end ="2025-01-01" )
# [*********************100%***********************]  21 of 21 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\850778035.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret=close.pct_change().dropna()
# Ticker          ABBV  BRK      COST      GOOG        HD       JNJ       JPM  \
# Date
# 2020-10-01 -0.005138  0.0  0.009746  0.013943 -0.000324 -0.010478  0.007271
# 2020-10-02 -0.011705  0.0 -0.009624 -0.021254  0.006088 -0.007331  0.009488
# 2020-10-05  0.021017  0.0  0.010056  0.018925  0.009989  0.013608  0.021136
# 2020-10-06 -0.023200  0.0 -0.000642 -0.021924 -0.019957 -0.013290 -0.010299
# 2020-10-07  0.013738  0.0  0.013032  0.004713  0.022860  0.011076  0.017445
#
# Ticker           LLY        MA      NFLX  ...      ORCL        PG      PLTR  \
# Date                                      ...
# ...

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# ABBV    0.000922  0.013839
# BRK     0.000000  0.000000
# COST    0.001062  0.014198
# GOOG    0.001080  0.019250
# HD      0.000522  0.014871
# JNJ     0.000135  0.010125
# JPM     0.001089  0.015879
# LLY     0.001773  0.019116
# MA      0.000564  0.015948
# NFLX    0.000961  0.028385
# NVDA    0.002682  0.032804
# ORCL    0.001197  0.018862
# PG      0.000329  0.010566
# PLTR    0.002931  0.045144
# PM      0.000732  0.012820
# SPY     0.000635  0.010369
# TSLA    0.001680  0.037775
# V       0.000561  0.014441
# WFC     0.001318  0.020125
# WMT     0.000753  0.012288
# XOM     0.001418  0.018572

# %%
summary["mean"]=summary["mean"] * 252
summary["std"]=summary["std"]*np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# ABBV    0.232240  0.219688
# BRK     0.000000  0.000000
# COST    0.267554  0.225392
# GOOG    0.272084  0.305585
# HD      0.131584  0.236077
# JNJ     0.034048  0.160731
# JPM     0.274465  0.252070
# LLY     0.446736  0.303463
# MA      0.142011  0.253166
# NFLX    0.242258  0.450604
# NVDA    0.675973  0.520740
# ORCL    0.301642  0.299427
# PG      0.082953  0.167732
# PLTR    0.738649  0.716634
# PM      0.184479  0.203508
# SPY     0.160001  0.164609
# TSLA    0.423292  0.599664
# V       0.141352  0.229249
# WFC     0.332043  0.319478
# WMT     0.189766  0.195062
# XOM     0.357332  0.294824

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/Return",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
del ret["BRK"]

# %%
RR = (summary["mean"] / summary["std"]).sort_values(ascending=False)
RR
# Out:
# Ticker
# LLY     1.472123
# NVDA    1.298100
# XOM     1.212015
# COST    1.187064
# JPM     1.088843
# ABBV    1.057139
# WFC     1.039329
# PLTR    1.030720
# ORCL    1.007396
# WMT     0.972850
# SPY     0.972011
# PM      0.906495
# GOOG    0.890370
# TSLA    0.705882
# V       0.616586
# MA      0.560938
# HD      0.557378
# NFLX    0.537630
# PG      0.494554
# JNJ     0.211835
# BRK          NaN
# dtype: float64

# %%
ret.cov()
# Out:
# Ticker      ABBV      COST      GOOG        HD       JNJ       JPM       LLY  \
# Ticker
# ABBV    0.000192  0.000035  0.000032  0.000042  0.000060  0.000052  0.000078
# COST    0.000035  0.000202  0.000114  0.000109  0.000031  0.000048  0.000065
# GOOG    0.000032  0.000114  0.000371  0.000102  0.000024  0.000089  0.000067
# HD      0.000042  0.000109  0.000102  0.000221  0.000039  0.000072  0.000058
# JNJ     0.000060  0.000031  0.000024  0.000039  0.000103  0.000041  0.000054
# JPM     0.000052  0.000048  0.000089  0.000072  0.000041  0.000252  0.000030
# LLY     0.000078  0.000065  0.000067  0.000058  0.000054  0.000030  0.000365
# MA      0.000051  0.000082  0.000141  0.000089  0.000040  0.000121  0.000058
# NFLX    0.000020  0.000139  0.000225  0.000114  0.000010  0.000079  0.000078
# NVDA    0.000015  0.000205  0.000337  0.000172 -0.000015  0.000127  0.000128
# ORCL    0.000027  0.000098  0.000126  0.000089  0.000027  0.000079  0.000083
# ...

# %%
ret.corr()
# Out:
# Ticker      ABBV      COST      GOOG        HD       JNJ       JPM       LLY  \
# Ticker
# ABBV    1.000000  0.179653  0.120805  0.203217  0.425207  0.234950  0.295785
# COST    0.179653  1.000000  0.415288  0.513928  0.217973  0.214256  0.239234
# GOOG    0.120805  0.415288  1.000000  0.355325  0.123562  0.290153  0.183340
# HD      0.203217  0.513928  0.355325  1.000000  0.261157  0.306182  0.205295
# JNJ     0.425207  0.217973  0.123562  0.261157  1.000000  0.256430  0.276968
# JPM     0.234950  0.214256  0.290153  0.306182  0.256430  1.000000  0.097954
# LLY     0.295785  0.239234  0.183340  0.205295  0.276968  0.097954  1.000000
# MA      0.230144  0.361197  0.460473  0.377288  0.245197  0.476422  0.189084
# NFLX    0.051949  0.345983  0.412191  0.270982  0.035587  0.174567  0.143560
# NVDA    0.033653  0.440519  0.533986  0.353325 -0.044259  0.242960  0.203902
# ORCL    0.103373  0.367143  0.346634  0.318365  0.141343  0.262719  0.231119
# ...

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds",annot=True,annot_kws={"size":10},vmax=0.6)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
#LLY,NVDA,XOM,COST,ABBV

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()

# %%
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
#mean returns are misleading

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\3374653147.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01" )
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY[["Close"]]

# %%
spy
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29   24.380451
# 1993-02-01   24.553846
# 1993-02-02   24.605854
# 1993-02-03   24.865990
# 1993-02-04   24.970022
# ...                ...
# 2024-12-24  597.729492
# 2024-12-26  597.769348
# 2024-12-27  591.476868
# 2024-12-30  584.727173
# 2024-12-31  582.599915
#
# [8038 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
# Price           Close
# Ticker            SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  24.781007
# 1993-02-12  24.817420
# 1993-02-16  24.774069
# 1993-02-17  24.723783
# 1993-02-18  24.645751
# 1993-02-19  24.565983

# %%
spy.rolling(window=10).median()
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-12-24  598.168518
# 2024-12-26  597.749420
# 2024-12-27  594.603180
# 2024-12-30  591.317841
# 2024-12-31  589.399323
#
# [8038 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-12-24  601.827393
# 2024-12-26  601.163574
# 2024-12-27  601.163574
# 2024-12-30  601.163574
# 2024-12-31  598.686829
#
# [8038 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
# Price           Close
# Ticker            SPY
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04  24.970022
# 1993-02-05  24.970022
# 1993-02-08  24.970022
# 1993-02-09  24.970022
# 1993-02-10  24.970022
# 1993-02-11  24.970022
# 1993-02-12  24.970022
# 1993-02-16  24.970022
# 1993-02-17  24.970022
# 1993-02-18  24.970022
# 1993-02-19  24.952684

# %%
spy
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29   24.380451
# 1993-02-01   24.553846
# 1993-02-02   24.605854
# 1993-02-03   24.865990
# 1993-02-04   24.970022
# ...                ...
# 2024-12-24  597.729492
# 2024-12-26  597.769348
# 2024-12-27  591.476868
# 2024-12-30  584.727173
# 2024-12-31  582.599915
#
# [8038 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2186649457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy.head(52)
# Out:
# Price           Close      SMA50
# Ticker            SPY
# Date
# 1993-01-29  24.380451        NaN
# 1993-02-01  24.553846        NaN
# 1993-02-02  24.605854        NaN
# 1993-02-03  24.865990        NaN
# 1993-02-04  24.970022        NaN
# 1993-02-05  24.952684        NaN
# 1993-02-08  24.952684        NaN
# 1993-02-09  24.779249        NaN
# 1993-02-10  24.813950        NaN
# 1993-02-11  24.935335        NaN
# 1993-02-12  24.744585        NaN
# 1993-02-16  24.120337        NaN
# 1993-02-17  24.102995        NaN
# 1993-02-18  24.085670        NaN
# 1993-02-19  24.172340        NaN
# 1993-02-22  24.259056        NaN
# 1993-02-23  24.241703        NaN
# 1993-02-24  24.553846        NaN
# 1993-02-25  24.605854        NaN
# 1993-02-26  24.640543        NaN
# 1993-03-01  24.571190        NaN
# 1993-03-02  24.935335        NaN
# 1993-03-03  25.039389        NaN
# 1993-03-04  24.900654        NaN
# 1993-03-05  24.831285        NaN
# 1993-03-08  25.386175        NaN
# ...

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\1840552259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
# Price            Close       SMA50      SMA200
# Ticker             SPY
# Date
# 1993-01-29   24.380451         NaN         NaN
# 1993-02-01   24.553846         NaN         NaN
# 1993-02-02   24.605854         NaN         NaN
# 1993-02-03   24.865990         NaN         NaN
# 1993-02-04   24.970022         NaN         NaN
# ...                ...         ...         ...
# 2024-12-24  597.729492  586.615475  545.387164
# 2024-12-26  597.769348  587.082780  545.839984
# 2024-12-27  591.476868  587.374303  546.265317
# ...

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#LLY,NVDA,XOM,COST,ABBV

# %%
tickers=["NVDA","LLY", "XOM","COST","ABBV"]

# %%
close = yf.download(tickers, start="2012-01-29", end="2025-01-01")["Close"]
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2790204886.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   close = yf.download(tickers, start="2012-01-29", end="2025-01-01")["Close"]
# [*********************100%***********************]  5 of 5 completed

# %%
sma50 = close.rolling(50, min_periods=50).mean()

# %%
data1 = pd.concat({"Close": close, "SMA50": sma50}, axis=1)

# %%
data1.head(52)
# Out:
#            Close                                            SMA50             \
# Ticker      ABBV       COST        LLY      NVDA        XOM  ABBV       COST
# Date
# 2012-01-30   NaN  59.428013  28.800152  0.339267  50.132805   NaN        NaN
# 2012-01-31   NaN  60.033672  29.159702  0.338579  49.106575   NaN        NaN
# 2012-02-01   NaN  60.726944  29.203722  0.342247  49.241455   NaN        NaN
# 2012-02-02   NaN  62.397968  29.056967  0.355084  48.983425   NaN        NaN
# 2012-02-03   NaN  62.288513  28.990919  0.362649  49.798531   NaN        NaN
# 2012-02-06   NaN  62.055012  29.093651  0.359898  50.285275   NaN        NaN
# 2012-02-07   NaN  61.704723  28.983595  0.360815  50.631256   NaN        NaN
# 2012-02-08   NaN  61.675430  29.189039  0.373881  50.306931   NaN        NaN
# 2012-02-09   NaN  61.858387  28.998266  0.373652  50.047508   NaN        NaN
# 2012-02-10   NaN  61.616901  28.844179  0.364483  49.410725   NaN        NaN
# ...

# %%
tickers = data1.columns.levels[1]      

for tkr in tickers:
    fig, ax = plt.subplots(figsize=(10, 5))     
    data1["Close", tkr].plot(ax=ax, label="Close")     
    data1["SMA50", tkr].plot(ax=ax, label="SMA50")     
    ax.set_title(f"{tkr} — Close vs. 50-Day SMA")
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
sma200 = close.rolling(200, min_periods=200).mean()

# %%
data1 = pd.concat({"Close": close, "SMA50": sma50, "SMA200": sma200}, axis=1)

# %%
tickers = data1.columns.levels[1]      

for tkr in tickers:
    fig, ax = plt.subplots(figsize=(10, 5))     
    data1["Close", tkr].plot(ax=ax, label="Close")      
    data1["SMA50", tkr].plot(ax=ax, label="SMA50")
    data1["SMA200", tkr].plot(ax=ax, label="SMA200")
    ax.set_title(f"{tkr} — Close vs. 50-Day SMA")
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
#short when SMA200 crosses above SMA50 over a certain threshold, long when it crosses back

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()
spy
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\2264221835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()
# Price            Close       SMA50      SMA200      EMA100
# Ticker             SPY
# Date
# 1993-01-29   24.380451         NaN         NaN         NaN
# 1993-02-01   24.553846         NaN         NaN         NaN
# 1993-02-02   24.605854         NaN         NaN         NaN
# 1993-02-03   24.865990         NaN         NaN         NaN
# 1993-02-04   24.970022         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-12-24  597.729492  586.615475  545.387164  571.965750
# ...

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
spy
# Out:
# Price            Close       SMA50      SMA200      EMA100        Day Quarter
# Ticker             SPY
# Date
# 1993-01-29   24.380451         NaN         NaN         NaN     Friday       1
# 1993-02-01   24.553846         NaN         NaN         NaN     Monday       1
# 1993-02-02   24.605854         NaN         NaN         NaN    Tuesday       1
# 1993-02-03   24.865990         NaN         NaN         NaN  Wednesday       1
# 1993-02-04   24.970022         NaN         NaN         NaN   Thursday       1
# ...                ...         ...         ...         ...        ...     ...
# 2024-12-24  597.729492  586.615475  545.387164  571.965750    Tuesday       4
# 2024-12-26  597.769348  587.082780  545.839984  572.476713   Thursday       4
# 2024-12-27  591.476868  587.374303  546.265317  572.852953     Friday       4
# 2024-12-30  584.727173  587.529843  546.661907  573.088086     Monday       4
# 2024-12-31  582.599915  587.598451  547.065212  573.276440    Tuesday       4
#
# ...

# %%
SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\3374653147.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01" )
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY[["Close"]]

# %%
spy
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29   24.380451
# 1993-02-01   24.553846
# 1993-02-02   24.605854
# 1993-02-03   24.865990
# 1993-02-04   24.970022
# ...                ...
# 2024-12-24  597.729492
# 2024-12-26  597.769348
# 2024-12-27  591.476868
# 2024-12-30  584.727173
# 2024-12-31  582.599915
#
# [8038 rows x 1 columns]

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
# Price            Close
# Ticker             SPY
# Date
# 1993-01-29   24.380451
# 1993-02-01   24.553846
# 1993-02-02   24.605854
# 1993-02-03   24.865990
# 1993-02-04   24.970022
# ...                ...
# 2024-12-24  597.729492
# 2024-12-26  597.769348
# 2024-12-27  591.476868
# 2024-12-30  584.727173
# 2024-12-31  582.599915
#
# [8038 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
# Price            Close
# Ticker             SPY
# 2010-12-31   96.750145
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03   97.750336
# 2011-01-04   97.696495
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  295.913513
# 2019-12-31  296.632385
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.ffill()
# Out:
# Price            Close
# Ticker             SPY
# 2010-12-31   96.750145
# 2011-01-01   96.750145
# 2011-01-02   96.750145
# 2011-01-03   97.750336
# 2011-01-04   97.696495
# ...                ...
# 2019-12-28  297.553955
# 2019-12-29  297.553955
# 2019-12-30  295.913513
# 2019-12-31  296.632385
# 2020-01-01  296.632385
#
# [3289 rows x 1 columns]

# %%
spy.bfill()
# Out:
# Price            Close
# Ticker             SPY
# 2010-12-31   96.750145
# 2011-01-01   97.750336
# 2011-01-02   97.750336
# 2011-01-03   97.750336
# 2011-01-04   97.696495
# ...                ...
# 2019-12-28  295.913513
# 2019-12-29  295.913513
# 2019-12-30  295.913513
# 2019-12-31  296.632385
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01",interval="1wk" )
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\3746346289.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   SPY = yf.download("SPY", start ="1993-01-29",end ="2025-01-01",interval="1wk" )
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 1993-01-25   24.380440   24.397780   24.276398   24.397780    1003200
# 1993-02-01   24.952675   25.022036   24.397786   24.397786    2234800
# 1993-02-08   24.744600   25.039385   24.709920   24.952684    1159800
# 1993-02-15   24.172363   24.675232   23.756196   24.675232     998700
# 1993-02-22   24.640541   24.657881   24.120333   24.241715    1024300
# ...                ...         ...         ...         ...        ...
# 2024-12-02  602.174133  603.422460  596.754882  597.378985  161443900
# 2024-12-09  598.607605  602.788447  596.546874  602.055318  168103400
# 2024-12-16  585.668701  602.144508  575.523599  600.380983  419353600
# 2024-12-23  591.476868  598.902482  584.170475  587.381337  196984300
# 2024-12-30  582.599915  588.226279  580.939787  584.399164  113631500
#
# [1667 rows x 5 columns]

# %% [markdown]
# ## Cummaltive returns, drawdowns etc..

# %%
apple=yf.download("AAPL", start ="1980-12-12",end ="2025-01-01")
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\1161041780.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple=yf.download("AAPL", start ="1980-12-12",end ="2025-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
apple.columns = apple.columns.droplevel("Ticker")

# %%
apple
# Out:
# Price            Close        High         Low        Open     Volume
# Date
# 1980-12-12    0.098597    0.099025    0.098597    0.098597  469033600
# 1980-12-15    0.093453    0.093881    0.093453    0.093881  175884800
# 1980-12-16    0.086594    0.087022    0.086594    0.087022  105728000
# 1980-12-17    0.088737    0.089165    0.088737    0.088737   86441600
# 1980-12-18    0.091309    0.091738    0.091309    0.091309   73449600
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.578674  257.588630  254.675658  254.875189   23234700
# 2024-12-26  258.396667  259.474086  257.010028  257.568678   27237100
# 2024-12-27  254.974930  258.077462  252.451019  257.209530   42355300
# 2024-12-30  251.593079  252.889953  250.146571  251.623005   35557500
# 2024-12-31  249.817368  252.670486  248.829744  251.832511   39480700
#
# [11105 rows x 5 columns]

# %%
apple = apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.098597
# 1980-12-15    0.093453
# 1980-12-16    0.086594
# 1980-12-17    0.088737
# 1980-12-18    0.091309
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593079
# 2024-12-31  249.817368
#
# [11105 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.098597        NaN
# 1980-12-15    0.093453  -0.053581
# 1980-12-16    0.086594  -0.076231
# 1980-12-17    0.088737   0.024450
# 1980-12-18    0.091309   0.028579
# ...                ...        ...
# 2024-12-24  257.578674   0.011413
# 2024-12-26  258.396667   0.003171
# 2024-12-27  254.974930  -0.013331
# 2024-12-30  251.593079  -0.013352
# 2024-12-31  249.817368  -0.007083
#
# [11105 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.093453  -0.053581
# 1980-12-16    0.086594  -0.076231
# 1980-12-17    0.088737   0.024450
# 1980-12-18    0.091309   0.028579
# 1980-12-19    0.096882   0.059240
# ...                ...        ...
# 2024-12-24  257.578674   0.011413
# 2024-12-26  258.396667   0.003171
# 2024-12-27  254.974930  -0.013331
# 2024-12-30  251.593079  -0.013352
# 2024-12-31  249.817368  -0.007083
#
# [11104 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# np.float64(7.8374479901424445)

# %%
np.exp(apple.d_returns.sum())
# Out:
# np.float64(2533.7304708835463)

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.093453  -0.053581     0.947829
# 1980-12-16    0.086594  -0.076231     0.878261
# 1980-12-17    0.088737   0.024450     0.899998
# 1980-12-18    0.091309   0.028579     0.926091
# 1980-12-19    0.096882   0.059240     0.982610
# ...                ...        ...          ...
# 2024-12-24  257.578674   0.011413  2612.448214
# 2024-12-26  258.396667   0.003171  2620.744572
# 2024-12-27  254.974930  -0.013331  2586.040175
# 2024-12-30  251.593079  -0.013352  2551.740320
# 2024-12-31  249.817368  -0.007083  2533.730471
#
# [11104 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="APPLE buy and hold", fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE buy and hold'}, xlabel='Date'>

# %%
apple.d_returns.mean()*252
# Out:
# np.float64(0.17786715539588402)

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# np.float64(0.44766060078302516)

# %%
sharpe = (apple.d_returns.mean() * 252) / (apple.d_returns.std() * np.sqrt(252))

# %%
sharpe
# Out:
# np.float64(0.39732590959483105)

# %%
#how to calculate drawdowns
apple["cummmax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829
# 1980-12-17    0.088737   0.024450     0.899998     0.947829
# 1980-12-18    0.091309   0.028579     0.926091     0.947829
# 1980-12-19    0.096882   0.059240     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-12-24  257.578674   0.011413  2612.448214  2612.448214
# 2024-12-26  258.396667   0.003171  2620.744572  2620.744572
# 2024-12-27  254.974930  -0.013331  2586.040175  2620.744572
# 2024-12-30  251.593079  -0.013352  2551.740320  2620.744572
# 2024-12-31  249.817368  -0.007083  2533.730471  2620.744572
#
# [11104 rows x 4 columns]

# %%
apple[["cummreturns","cummmax"]].plot(figsize=(12,8),title="APPLE buy and hold+cummax", fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE buy and hold+cummax'}, xlabel='Date'>

# %%
apple["drawdown"]=apple["cummmax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829   0.069568
# 1980-12-17    0.088737   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.091309   0.028579     0.926091     0.947829   0.021738
# 1980-12-19    0.096882   0.059240     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-12-24  257.578674   0.011413  2612.448214  2612.448214   0.000000
# 2024-12-26  258.396667   0.003171  2620.744572  2620.744572   0.000000
# 2024-12-27  254.974930  -0.013331  2586.040175  2620.744572  34.704397
# 2024-12-30  251.593079  -0.013352  2551.740320  2620.744572  69.004251
# 2024-12-31  249.817368  -0.007083  2533.730471  2620.744572  87.014101
#
# [11104 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# np.float64(560.1040323665186)

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829    0.069568
# 1980-12-17    0.088737   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.091309   0.028579     0.926091     0.947829    0.021738
# 1980-12-19    0.096882   0.059240     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  127.952583   0.027931  1297.737473  1811.883293  514.145821
# 2022-12-30  128.268478   0.002466  1300.941385  1811.883293  510.941908
# 2023-01-03  123.470604  -0.038122  1252.279754  1811.883293  559.603540
# 2023-01-04  124.744125   0.010262  1265.196230  1811.883293  546.687064
# 2023-01-05  123.421257  -0.010661  1251.779261  1811.883293  560.104032
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummmax"]-apple["cummreturns"])/apple["cummmax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1980-12-15    0.093453  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.086594  -0.076231     0.878261     0.947829   0.069568
# 1980-12-17    0.088737   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.091309   0.028579     0.926091     0.947829   0.021738
# 1980-12-19    0.096882   0.059240     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-12-24  257.578674   0.011413  2612.448214  2612.448214   0.000000
# 2024-12-26  258.396667   0.003171  2620.744572  2620.744572   0.000000
# 2024-12-27  254.974930  -0.013331  2586.040175  2620.744572  34.704397
# 2024-12-30  251.593079  -0.013352  2551.740320  2620.744572  69.004251
# 2024-12-31  249.817368  -0.007083  2533.730471  2620.744572  87.014101
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050463
# ...

# %%
apple["drawdown%"].max()
# Out:
# np.float64(0.8180143409810345)

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('2003-04-17 00:00:00')

# %%
apple.loc[(apple.index<='2003-04-17')]
# Out:
#                Close  d_returns  cummreturns    cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.093453  -0.053581     0.947829   0.947829  0.000000   0.000000
# 1980-12-16  0.086594  -0.076231     0.878261   0.947829  0.069568   0.073398
# 1980-12-17  0.088737   0.024450     0.899998   0.947829  0.047831   0.050463
# 1980-12-18  0.091309   0.028579     0.926091   0.947829  0.021738   0.022935
# 1980-12-19  0.096882   0.059240     0.982610   0.982610  0.000000   0.000000
# ...              ...        ...          ...        ...       ...        ...
# 2003-04-11  0.198357  -0.084927     2.011806  10.987783  8.975977   0.816905
# 2003-04-14  0.204068   0.028383     2.069725  10.987783  8.918059   0.811634
# 2003-04-15  0.201213  -0.014091     2.040765  10.987783  8.947018   0.814270
# 2003-04-16  0.198959  -0.011263     2.017909  10.987783  8.969874   0.816350
# 2003-04-17  0.197156  -0.009105     1.999619  10.987783  8.988164   0.818014
#
# [5641 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.309167
# 1991-01-03    0.305614
# 1991-01-04    0.307390
# 1991-01-07    0.307390
# 1991-01-08    0.307390
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593079
# 2024-12-31  249.817368
#
# [8564 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
STOCK
# Out:
# Price            Close
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 1993-01-29         NaN    6.280787    5.852823         NaN    5.361428
# 1993-02-01         NaN    6.197047    5.801030         NaN    5.394323
# 1993-02-02         NaN    6.197047    5.723336         NaN    5.460106
# 1993-02-03         NaN    6.280787    5.839875         NaN    5.482034
# 1993-02-04         NaN    6.280787    5.826927         NaN    5.501555
# ...                ...         ...         ...         ...         ...
# 2024-12-24  176.685577  956.515503  792.676208  140.197372  104.494308
# 2024-12-26  175.900314  953.841919  791.151978  139.907410  104.582695
# 2024-12-27  174.732224  937.441406  780.223267  136.987885  104.572876
# 2024-12-30  172.955551  919.993530  770.928467  137.467804  103.865776
# 2024-12-31  174.427933  914.067749  769.095276  134.268326  105.643356
#
# [8038 rows x 5 columns]

# %%
data.plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.322214    0.426368    0.409260
# 1991-05-24    0.327569    0.423624    0.409444
# 1991-05-28    0.328461    0.420757    0.409673
# 1991-05-29    0.335602    0.417818    0.409955
# 1991-05-30    0.340064    0.414720    0.410281
# ...                ...         ...         ...
# 2024-12-24  257.578674  235.255513  229.057160
# 2024-12-26  258.396667  235.762829  229.558168
# 2024-12-27  254.974930  236.242965  230.045264
# 2024-12-30  251.593079  236.648090  230.472762
# 2024-12-31  249.817368  236.960901  230.847765
#
# [8465 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.322214    0.426368    0.409260         1
# 1991-05-24    0.327569    0.423624    0.409444         1
# 1991-05-28    0.328461    0.420757    0.409673         1
# 1991-05-29    0.335602    0.417818    0.409955         1
# 1991-05-30    0.340064    0.414720    0.410281         1
# ...                ...         ...         ...       ...
# 2024-12-24  257.578674  235.255513  229.057160         1
# 2024-12-26  258.396667  235.762829  229.558168         1
# 2024-12-27  254.974930  236.242965  230.045264         1
# 2024-12-30  251.593079  236.648090  230.472762         1
# 2024-12-31  249.817368  236.960901  230.847765         1
#
# [8465 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["reutrnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["reutrnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  reutrnsb&h  strategy
# Date
# 1991-05-23    0.322214    0.426368    0.409260         1         NaN       NaN
# 1991-05-24    0.327569    0.423624    0.409444         1    0.016483  0.016483
# 1991-05-28    0.328461    0.420757    0.409673         1    0.002721  0.002721
# 1991-05-29    0.335602    0.417818    0.409955         1    0.021507  0.021507
# 1991-05-30    0.340064    0.414720    0.410281         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2024-12-24  257.578674  235.255513  229.057160         1    0.011413  0.011413
# 2024-12-26  258.396667  235.762829  229.558168         1    0.003171  0.003171
# 2024-12-27  254.974930  236.242965  230.045264         1   -0.013331 -0.013331
# 2024-12-30  251.593079  236.648090  230.472762         1   -0.013352 -0.013352
# 2024-12-31  249.817368  236.960901  230.847765         1   -0.007083 -0.007083
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["reutrnsb&h","strategy"]].sum()
# Out:
# reutrnsb&h    6.653271
# strategy      1.749662
# dtype: float64

# %%
data[["reutrnsb&h","strategy"]].sum().apply(np.exp) #what 1 dollar will be
# Out:
# reutrnsb&h    775.316049
# strategy        5.752660
# dtype: float64

# %%
data[["reutrnsb&h","strategy"]].std()*np.sqrt(252)  #ann std
# Out:
# reutrnsb&h    0.430135
# strategy      0.430303
# dtype: float64

# %% [markdown]
# data.Close.plot(figsize=(12,8))

# %% [markdown]
# ## long biased strat

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["reutrnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["reutrnsb&h","strategy2"]].sum()
# Out:
# reutrnsb&h    6.636788
# strategy2     4.184984
# dtype: float64

# %%
data[["reutrnsb&h","strategy2"]].sum().apply(np.exp) #what 1 dollar will be
# Out:
# reutrnsb&h    762.641466
# strategy2      65.692437
# dtype: float64

# %%
data[["reutrnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# reutrnsb&h    0.430152
# strategy2     0.332933
# dtype: float64

# %% [markdown]
# ## strategy 2 is better than strategy 1

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.430319
# strategy2    0.332933
# dtype: float64

# %% [markdown]
# ## Best SMA for the 5 stocks
# ## Create bias strategy
# ## compare drawdowns
# ## pick the best 3 stocks for portfolio

# %%
sma_50 = close.rolling(50, min_periods=50).mean()

# %%
sma_100 = close.rolling(100, min_periods=100).mean()

# %%
sma_100
# Out:
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 2012-01-30         NaN         NaN         NaN         NaN         NaN
# 2012-01-31         NaN         NaN         NaN         NaN         NaN
# 2012-02-01         NaN         NaN         NaN         NaN         NaN
# 2012-02-02         NaN         NaN         NaN         NaN         NaN
# 2012-02-03         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2024-12-24  183.887314  906.347868  858.869200  129.307963  113.978720
# 2024-12-26  183.851001  907.897874  859.080819  129.702854  113.915518
# 2024-12-27  183.789860  909.133935  859.005169  130.030563  113.858112
# 2024-12-30  183.693424  910.261072  859.045540  130.416453  113.778948
# 2024-12-31  183.583569  911.038738  858.340853  130.709768  113.696203
#
# [3252 rows x 5 columns]

# %%
data2 = pd.concat({"Close": close, "sma_50": sma_50, "sma_100": sma_100}, axis=1)

# %%
data2.head(52)
# Out:
#            Close                                            sma_50             \
# Ticker      ABBV       COST        LLY      NVDA        XOM   ABBV       COST
# Date
# 2012-01-30   NaN  59.428013  28.800152  0.339267  50.132805    NaN        NaN
# 2012-01-31   NaN  60.033672  29.159702  0.338579  49.106575    NaN        NaN
# 2012-02-01   NaN  60.726944  29.203722  0.342247  49.241455    NaN        NaN
# 2012-02-02   NaN  62.397968  29.056967  0.355084  48.983425    NaN        NaN
# 2012-02-03   NaN  62.288513  28.990919  0.362649  49.798531    NaN        NaN
# 2012-02-06   NaN  62.055012  29.093651  0.359898  50.285275    NaN        NaN
# 2012-02-07   NaN  61.704723  28.983595  0.360815  50.631256    NaN        NaN
# 2012-02-08   NaN  61.675430  29.189039  0.373881  50.306931    NaN        NaN
# 2012-02-09   NaN  61.858387  28.998266  0.373652  50.047508    NaN        NaN
# 2012-02-10   NaN  61.616901  28.844179  0.364483  49.410725    NaN        NaN
# ...

# %%
tickers1 = data2.columns.levels[1]      

for tkr in tickers1:
    fig, ax = plt.subplots(figsize=(10, 5))     
    data2["Close", tkr].plot(ax=ax, label="Close")      
    data2["sma_50", tkr].plot(ax=ax, label="sma_50")
    data2["sma_100", tkr].plot(ax=ax, label="sma_100")
    ax.set_title(f"{tkr} — C3")
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
data2.loc["2016"]
# Out:
#                 Close                                                 sma_50  \
# Ticker           ABBV        COST        LLY      NVDA        XOM       ABBV
# Date
# 2016-01-04  38.615620  134.620148  70.056046  0.789676  50.891747  39.048757
# 2016-01-05  38.454739  134.949234  71.104317  0.802362  51.325371  39.170750
# 2016-01-06  38.461449  133.700409  70.656258  0.769184  50.898315  39.265127
# 2016-01-07  38.347496  130.637405  68.821808  0.738690  50.083618  39.336715
# 2016-01-08  37.301846  128.350723  68.686546  0.722833  49.071835  39.377871
# ...               ...         ...        ...       ...        ...        ...
# 2016-12-23  43.401478  138.333923  64.053627  2.703861  61.702110  42.217232
# 2016-12-27  43.512871  138.308273  64.070961  2.889572  61.729321  42.249675
# 2016-12-28  43.352745  137.420700  63.419907  2.690809  61.423225  42.279333
# 2016-12-29  43.672997  137.523148  63.853977  2.744502  61.457237  42.295764
# ...

# %%
tickers1 = data2.columns.levels[1]      

for tkr in tickers1:
    fig, ax = plt.subplots(figsize=(10, 5))     
    data2["Close", tkr].loc["2016"].plot(ax=ax, label="Close")      
    data2["sma_50", tkr].loc["2016"].plot(ax=ax, label="sma_50")
    data2["sma_100", tkr].loc["2016"].plot(ax=ax, label="sma_100")
    ax.set_title(f"{tkr} — C3")
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    ax.legend()
    plt.tight_layout()
    plt.show()

# %%
data2.dropna(inplace=True)

# %%
data2
# Out:
#                  Close                                                  \
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 2013-05-24   28.053879   90.941490   42.340534    0.339229   55.770683
# 2013-05-28   28.023012   91.291306   42.653347    0.338996   56.288609
# 2013-05-29   27.090765   89.796654   42.035542    0.336896   56.105778
# 2013-05-30   27.504408   88.946007   42.293598    0.341329   56.111877
# 2013-05-31   26.356073   87.157227   41.574123    0.337596   55.124802
# ...                ...         ...         ...         ...         ...
# 2024-12-24  176.685593  956.515503  792.676208  140.197372  104.494308
# 2024-12-26  175.900314  953.841919  791.151978  139.907410  104.582695
# 2024-12-27  174.732224  937.441406  780.223267  136.987885  104.572876
# 2024-12-30  172.955551  919.993530  770.928467  137.467804  103.865776
# 2024-12-31  174.427933  914.067749  769.095276  134.268326  105.643356
#
# ...

# %%
data2[[f"position_{col}" for col in data2["sma_50"].columns]] = ((data2["sma_50"] > data2["sma_100"]).astype(int).replace(0, -1))

# %%
data2
# Out:
#                  Close                                                  \
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 2013-05-24   28.053879   90.941490   42.340534    0.339229   55.770683
# 2013-05-28   28.023012   91.291306   42.653347    0.338996   56.288609
# 2013-05-29   27.090765   89.796654   42.035542    0.336896   56.105778
# 2013-05-30   27.504408   88.946007   42.293598    0.341329   56.111877
# 2013-05-31   26.356073   87.157227   41.574123    0.337596   55.124802
# ...                ...         ...         ...         ...         ...
# 2024-12-24  176.685593  956.515503  792.676208  140.197372  104.494308
# 2024-12-26  175.900314  953.841919  791.151978  139.907410  104.582695
# 2024-12-27  174.732224  937.441406  780.223267  136.987885  104.572876
# 2024-12-30  172.955551  919.993530  770.928467  137.467804  103.865776
# 2024-12-31  174.427933  914.067749  769.095276  134.268326  105.643356
#
# ...

# %%
import matplotlib.pyplot as plt

tickers2 = data2["sma_50"].columns        
data_2016 = data2.loc["2016"]            

for ticker in tickers2:
    df = data_2016                        

    plt.figure(figsize=(12,6))
    ax1 = plt.gca()

    ax1.plot(df.index, df["Close"][ticker],     label=f"{ticker} Close", linewidth=1.5)
    ax1.plot(df.index, df["sma_50"][ticker],    label="SMA 50", linestyle='--')
    ax1.plot(df.index, df["sma_100"][ticker],   label="SMA 100", linestyle='--')

    ax2 = ax1.twinx()
    ax2.step(df.index, df[f"position_{ticker}"],
             label="Position", where="post",
             linestyle=":", alpha=0.7)
    ax2.set_ylim([-1.5, 1.5])
    ax2.set_ylabel("Position")

    ax1.set_title(f"{ticker} — 2016 Close vs SMAs & Signal")
    ax1.set_ylabel("Price")
    ax1.set_xlabel("Date")

    ax1.legend(loc="upper left")
    ax2.legend(loc="upper right")
    plt.tight_layout()
    plt.show()

# %%
data2[[f"returnsb&h_{col}" for col in data2["sma_50"].columns]] = (np.log(data2.Close.div(data2.Close.shift(1))))

# %%
data2
# Out:
#                  Close                                                  \
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 2013-05-24   28.053879   90.941490   42.340534    0.339229   55.770683
# 2013-05-28   28.023012   91.291306   42.653347    0.338996   56.288609
# 2013-05-29   27.090765   89.796654   42.035542    0.336896   56.105778
# 2013-05-30   27.504408   88.946007   42.293598    0.341329   56.111877
# 2013-05-31   26.356073   87.157227   41.574123    0.337596   55.124802
# ...                ...         ...         ...         ...         ...
# 2024-12-24  176.685593  956.515503  792.676208  140.197372  104.494308
# 2024-12-26  175.900314  953.841919  791.151978  139.907410  104.582695
# 2024-12-27  174.732224  937.441406  780.223267  136.987885  104.572876
# 2024-12-30  172.955551  919.993530  770.928467  137.467804  103.865776
# 2024-12-31  174.427933  914.067749  769.095276  134.268326  105.643356
#
# ...

# %%
for col in data2["sma_50"].columns:                # AAPL, MSFT, …
    data2[f"strategy_{col}"] = (
        data2[f"returnsb&h_{col}"]                 # that stock’s daily return
        * data2[f"position_{col}"].shift(1)        # yesterday’s signal
    )

# %%
data2
# Out:
#                  Close                                                  \
# Ticker            ABBV        COST         LLY        NVDA         XOM
# Date
# 2013-05-24   28.053879   90.941490   42.340534    0.339229   55.770683
# 2013-05-28   28.023012   91.291306   42.653347    0.338996   56.288609
# 2013-05-29   27.090765   89.796654   42.035542    0.336896   56.105778
# 2013-05-30   27.504408   88.946007   42.293598    0.341329   56.111877
# 2013-05-31   26.356073   87.157227   41.574123    0.337596   55.124802
# ...                ...         ...         ...         ...         ...
# 2024-12-24  176.685593  956.515503  792.676208  140.197372  104.494308
# 2024-12-26  175.900314  953.841919  791.151978  139.907410  104.582695
# 2024-12-27  174.732224  937.441406  780.223267  136.987885  104.572876
# 2024-12-30  172.955551  919.993530  770.928467  137.467804  103.865776
# 2024-12-31  174.427933  914.067749  769.095276  134.268326  105.643356
#
# ...

# %%
report = []                                          # collect results

for t in tickers:
    cols = [f"returnsb&h_{t}", f"strategy_{t}"]      # per-ticker columns
    df   = data2[cols]

    final_val   = df.sum().apply(np.exp)             # $1 grows to ...
    ann_sigma   = df.std() * np.sqrt(252)            # annualised σ
    sharpe      = (df.mean() / df.std()) * np.sqrt(252)

    # stash nicely
    report.append(pd.concat(
        [final_val.rename("Final_$1"),
         ann_sigma.rename("Ann_σ"),
         sharpe.rename("Sharpe")],
        axis=1
    ).assign(Ticker=t))

# bring all tickers together
summary = pd.concat(report, axis=0).set_index("Ticker", append=True).swaplevel(0,1)
print(summary)
# Out:
#                                  Final_$1     Ann_σ    Sharpe
# Ticker                 Ticker
#        returnsb&h_ABBV ABBV      6.217605  0.265235  0.594589
#        strategy_ABBV   ABBV      0.384233  0.265370 -0.311067
#        returnsb&h_COST COST     10.051163  0.207604  0.959310
#        strategy_COST   COST      2.230028  0.207937  0.332864
#        returnsb&h_LLY  LLY      18.164515  0.264414  0.946351
#        strategy_LLY    LLY       1.913393  0.264860  0.211429
#        returnsb&h_NVDA NVDA    395.803808  0.455853  1.132297
#        strategy_NVDA   NVDA    288.589881  0.455973  1.072209
#        returnsb&h_XOM  XOM       1.894245  0.264220  0.208656
#        strategy_XOM    XOM       0.848061  0.264241 -0.053825

# %% [markdown]
# ## Creating function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.droplevel("Ticker")
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]   = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]   = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
    data["strategy"] = data["returns"] * data.position.shift(1)
    data.dropna(inplace=True)

    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std() * np.sqrt(252)

    return ret, std

# %%
test_strategy("MSFT","2010-01-01","2020-01-01", (50,200))
# Out:
# C:\Users\benzh\AppData\Local\Temp\ipykernel_19564\646554108.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSFT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# (np.float64(1.0), np.float64(nan))
